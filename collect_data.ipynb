# %% [markdown]
# <a href="https://colab.research.google.com/github/lintangiqhtiar/root-cause-analysis/blob/main/collect_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install scrapy
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 933.5 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.2/311.2 kB 6.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 24.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 259.8/259.8 kB 15.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.9/104.9 kB 5.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 2.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.6/74.6 kB 3.8 MB/s eta 0:00:00
# ...

# %%
# !scrapy startproject playstore_scraper
# Out:
# New Scrapy project 'playstore_scraper', using template directory '/usr/local/lib/python3.11/dist-packages/scrapy/templates/project', created in:
#     /content/playstore_scraper
#
# You can start your first spider with:
#     cd playstore_scraper
#     scrapy genspider example example.com

# %%
pip install google_play_scraper
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 3.2 MB/s eta 0:00:00
# ...

# %%
import csv
import google_play_scraper
from google_play_scraper import reviews_all

# %%
# Tentukan nama paket aplikasi (misalnya untuk aplikasi Digital Korlantas POLRI)
package_name = 'superapps.polri.presisi.presisi'

# Mengambil semua ulasan
reviews = reviews_all(package_name, lang='id', country='ID')

# Tentukan nama file CSV
filename = 'polri_superapp_review.csv'

# Menyimpan hasil scraping ke dalam file CSV
with open(filename, mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    # Menulis header kolom
    writer.writerow(['Review', 'Rating', 'User', 'Date', 'Reply'])

    # Menulis data ulasan ke file CSV
    for review in reviews:
        writer.writerow([
            review['content'],  # Isi ulasan
            review['score'],    # Rating
            review['userName'], # Nama pengguna
            review['at'],       # Tanggal
            review.get('replyContent', 'No reply')  # Balasan (jika ada)
        ])

print(f'CSV file has been saved as {filename}')
# Out:
# CSV file has been saved as polri_superapp_review.csv

# %%
import pandas as pd

# %%
df = pd.read_csv('polri_superapp_review.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16335 entries, 0 to 16334
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Review  16335 non-null  object
#  1   Rating  16335 non-null  int64
#  2   User    16335 non-null  object
#  3   Date    16335 non-null  object
#  4   Reply   15859 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 638.2+ KB

# %%
df
# Out:
#                                                   Review  Rating  \
# 0      Apk ga jelas. Isi data udh sesuai ngirim data ...       1
# 1      Aplikasi bug terus, susah masuk Susah kirim da...       1
# 2      SUSAH VERIFIKASI LOG IN GAGAL TERUS PADAHAL KO...       1
# 3      Aplikasinya buat susah aja bukan mempermudah, ...       1
# 4      gabisa simpan registrasi error terus padahal j...       1
# ...                                                  ...     ...
# 16330  Waktu foto wajah susah ngelag trus pdhal signa...       1
# 16331                     Bingung, kenapa perlu NPWP ya?       2
# 16332                                                Bad       1
# 16333                             Masih di pertimbangkan       5
# 16334  Aplikasi tidak berfungsi, Pendaftaran OTP tida...       1
#
#                   User                 Date  \
# 0      Pengguna Google  2025-03-11 04:01:06
# 1      Pengguna Google  2025-03-11 03:51:42
# 2      Pengguna Google  2025-03-11 03:47:09
# ...

# %%
#ubah kolom review menjadi str
df['Review'] = df['Review'].astype(str)
#ubah rating jadi int
df['Rating'] = df['Rating'].astype(int)
#ubah date jadi format date
df['Date'] = pd.to_datetime(df['Date'])

# %%
#lihat jenis data per kolom
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16335 entries, 0 to 16334
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Review  16335 non-null  object
#  1   Rating  16335 non-null  int64
#  2   User    16335 non-null  object
#  3   Date    16335 non-null  datetime64[ns]
#  4   Reply   15859 non-null  object
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 638.2+ KB

# %%
df
# Out:
#                                                   Review  Rating  \
# 0      Apk ga jelas. Isi data udh sesuai ngirim data ...       1
# 1      Aplikasi bug terus, susah masuk Susah kirim da...       1
# 2      SUSAH VERIFIKASI LOG IN GAGAL TERUS PADAHAL KO...       1
# 3      Aplikasinya buat susah aja bukan mempermudah, ...       1
# 4      gabisa simpan registrasi error terus padahal j...       1
# ...                                                  ...     ...
# 16330  Waktu foto wajah susah ngelag trus pdhal signa...       1
# 16331                     Bingung, kenapa perlu NPWP ya?       2
# 16332                                                Bad       1
# 16333                             Masih di pertimbangkan       5
# 16334  Aplikasi tidak berfungsi, Pendaftaran OTP tida...       1
#
#                   User                Date  \
# 0      Pengguna Google 2025-03-11 04:01:06
# 1      Pengguna Google 2025-03-11 03:51:42
# 2      Pengguna Google 2025-03-11 03:47:09
# ...

# %%
# #seleksi data dari tahun 2024 dan 2022
# df = df[(df['Date'].dt.year == 2025) | (df['Date'].dt.year == 2022)]

# %%
df
# Out:
#                                                   Review  Rating  \
# 0      Apk ga jelas. Isi data udh sesuai ngirim data ...       1
# 1      Aplikasi bug terus, susah masuk Susah kirim da...       1
# 2      SUSAH VERIFIKASI LOG IN GAGAL TERUS PADAHAL KO...       1
# 3      Aplikasinya buat susah aja bukan mempermudah, ...       1
# 4      gabisa simpan registrasi error terus padahal j...       1
# ...                                                  ...     ...
# 16330  Waktu foto wajah susah ngelag trus pdhal signa...       1
# 16331                     Bingung, kenapa perlu NPWP ya?       2
# 16332                                                Bad       1
# 16333                             Masih di pertimbangkan       5
# 16334  Aplikasi tidak berfungsi, Pendaftaran OTP tida...       1
#
#                   User                Date  \
# 0      Pengguna Google 2025-03-11 04:01:06
# 1      Pengguna Google 2025-03-11 03:51:42
# 2      Pengguna Google 2025-03-11 03:47:09
# ...

# %%
#menghitung jumlah value per rating
df['Rating'].value_counts()
# Out:
# Rating
# 1    8733
# 5    5351
# 2    1011
# 3     727
# 4     513
# Name: count, dtype: int64

# %%
pip install transformers

# %%
# !pip install --upgrade torch torchvision torchaudio

# %%
# Use a pipeline as a high-level helper
from transformers import pipeline

# %%
sentiment_analysis = pipeline("sentiment-analysis", model="ayameRushia/bert-base-indonesian-1.5G-sentiment-analysis-smsa")
print(sentiment_analysis("Saya sangat menyukai aplikasinya."))
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/899 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/443M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/387 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/230k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/443M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/476k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Device set to use cpu
# ...

# %%
df['sentimen']=df['Review'].apply(lambda x : sentiment_analysis(x))

# %%
df.head(5)
# Out:
#                                               Review  Rating             User  \
# 0  Apk ga jelas. Isi data udh sesuai ngirim data ...       1  Pengguna Google
# 1  Aplikasi bug terus, susah masuk Susah kirim da...       1  Pengguna Google
# 2  SUSAH VERIFIKASI LOG IN GAGAL TERUS PADAHAL KO...       1  Pengguna Google
# 3  Aplikasinya buat susah aja bukan mempermudah, ...       1  Pengguna Google
# 4  gabisa simpan registrasi error terus padahal j...       1  Pengguna Google
#
#                  Date Reply                                           sentimen
# 0 2025-03-11 04:01:06   NaN  [{'label': 'Neutral', 'score': 0.9324769973754...
# 1 2025-03-11 03:51:42   NaN  [{'label': 'Negative', 'score': 0.999845504760...
# 2 2025-03-11 03:47:09   NaN  [{'label': 'Negative', 'score': 0.999675750732...
# 3 2025-03-11 03:45:46   NaN  [{'label': 'Negative', 'score': 0.999859929084...
# 4 2025-03-11 03:45:33   NaN  [{'label': 'Negative', 'score': 0.997543334960...

# %%
#melihat 5 baris terakhir
df.tail(5)

# %%
#simpan df
df.to_csv('datatrain_sentimen.csv', index=False)

# %%
# df[df['Rating']==5]

# %%
# df[df['sentimen']=='label' ]

# %%
df["label"]=df["sentimen"].apply(lambda x: x[0]['label'] if isinstance(x, list) and len(x) > 0 else None)
df["confidence"]=df["sentimen"].apply(lambda x: x[0]['score'] if isinstance(x, list) and len(x) > 0 else None)
df.drop("sentimen", axis=1, inplace=True)

# %%
df.head()
# Out:
#                                               Review  Rating             User  \
# 0  Apk ga jelas. Isi data udh sesuai ngirim data ...       1  Pengguna Google
# 1  Aplikasi bug terus, susah masuk Susah kirim da...       1  Pengguna Google
# 2  SUSAH VERIFIKASI LOG IN GAGAL TERUS PADAHAL KO...       1  Pengguna Google
# 3  Aplikasinya buat susah aja bukan mempermudah, ...       1  Pengguna Google
# 4  gabisa simpan registrasi error terus padahal j...       1  Pengguna Google
#
#                  Date Reply     label  confidence
# 0 2025-03-11 04:01:06   NaN   Neutral    0.932477
# 1 2025-03-11 03:51:42   NaN  Negative    0.999846
# 2 2025-03-11 03:47:09   NaN  Negative    0.999676
# 3 2025-03-11 03:45:46   NaN  Negative    0.999860
# 4 2025-03-11 03:45:33   NaN  Negative    0.997543

# %%
#simpan df
df.to_csv('datatrain_sentimen_labeled.csv', index=False)

# %%
df.drop(["confidence"], axis=1, inplace=True)

# %%
#mengubah nama kolom Review menjadi huruf kecil
df.rename(columns={"Review":"review"}, inplace=True)

# %%
df.to_csv('data_train_sentimen.csv', index=False)
